# %% [markdown]
# # CoinMarketCap API
# - In order to manipulate the DataFrames below, you'll need to sign up for your API Key at this link:
#  https://pro.coinmarketcap.com/signup/

# %%
your_key_here = input('Enter your unique API Key: ')

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

headers ={'Accepts':'application/json','X-CMC_PRO_API_KEY':your_key_here,}

url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {'start':'1','limit':'5000','convert':'USD'}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data_jason = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %% [markdown]
# ### Cryptocurrency Prices sorted by Market Cap

# %%
df = pd.DataFrame(data_jason['data'])
df[['cmc_rank','symbol','name','max_supply','circulating_supply','quote']][0:10] #top 10
# Out:
#    cmc_rank symbol          name    max_supply  circulating_supply  \
# 0         1    BTC       Bitcoin  2.100000e+07        1.872602e+07
# 1         2    ETH      Ethereum           NaN        1.161448e+08
# 2         3    BNB  Binance Coin  1.705328e+08        1.534329e+08
# 3         4   USDT        Tether           NaN        6.167094e+10
# 4         5    ADA       Cardano  4.500000e+10        3.194831e+10
# 5         6   DOGE      Dogecoin           NaN        1.298682e+11
# 6         7    XRP           XRP  1.000000e+11        4.615101e+10
# 7         8    DOT      Polkadot           NaN        9.447314e+08
# 8         9   USDC      USD Coin           NaN        2.284808e+10
# 9        10    UNI       Uniswap  1.000000e+09        5.649423e+08
#
#                                                quote
# 0  {'USD': {'price': 38987.61112357755, 'volume_2...
# 1  {'USD': {'price': 2844.4281536996587, 'volume_...
# 2  {'USD': {'price': 422.607348849398, 'volume_24...
# 3  {'USD': {'price': 1.00056287661484, 'volume_24...
# 4  {'USD': {'price': 1.84023387693006, 'volume_24...
# 5  {'USD': {'price': 0.40284395000615, 'volume_24...
# 6  {'USD': {'price': 1.04458987242755, 'volume_24...
# 7  {'USD': {'price': 27.26614016333529, 'volume_2...
# 8  {'USD': {'price': 1.00040039839415, 'volume_24...
# 9  {'USD': {'price': 28.50536892885259, 'volume_2...

# %% [markdown]
# ### List of Fiat Currencies and Symbols

# %%
fiat_url ='https://pro-api.coinmarketcap.com/v1/fiat/map'
fiat_params = {}

session = Session()
session.headers.update(headers)

try:
  response = session.get(fiat_url, params=fiat_params)
  data_jason2 = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
fiat = pd.DataFrame(data_jason2['data'])
fiat.head()
# Out:
#      id                  name sign symbol
# 0  2781  United States Dollar    $    USD
# 1  2782     Australian Dollar    $    AUD
# 2  2783        Brazilian Real   R$    BRL
# 3  2784       Canadian Dollar    $    CAD
# 4  2785           Swiss Franc   Fr    CHF

# %%
#Selecting specific currencies
fiat[(fiat['name'] == 'Chinese Yuan') | (fiat['name'] == 'Pound Sterling')]
# Out:
#       id            name sign symbol
# 6   2787    Chinese Yuan    ¥    CNY
# 10  2791  Pound Sterling    £    GBP

# %%
#Unique currency symbols
fiat.sign.unique()
# Out:
# array(['$', 'R$', 'Fr', '¥', 'Kč', 'kr', '€', '£', 'Ft', 'Rp', '₪', '₹',
#        '₩', 'RM', '₱', '₨', 'zł', '₽', 'S$', '฿', '₺', 'NT$', 'R', 'د.إ',
#        'лв', 'kn', 'lei', '₦', 'S/.', '₫', '₴', 'Bs.', 'L', '֏', '₼',
#        'KM', '৳', '.د.ب', 'Br', '₡', 'د.ج', '₾', '₵', 'Q', 'ع.د', '﷼',
#        'د.ا', 'Sh', 'с', '៛', 'د.ك', '₸', 'ل.ل', 'Rs', 'د.م.', 'ден',
#        'Ks', '₮', 'C$', 'ر.ع.', 'B/.', 'ر.ق', 'дин.', 'ر.س', 'د.ت',
#        "so'm"], dtype=object)
